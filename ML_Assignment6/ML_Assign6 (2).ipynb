# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model  import LinearRegression
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
df=pd.read_csv('/content/temperatures - temperatures.csv')

# %%
df.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
df.tail()
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 112  30.27  27.83  25.37   29.81    25.58    32.58    31.33    27.83
# 113  30.29  28.05  25.08   29.72    24.90    31.82    32.00    27.81
# 114  31.04  28.10  25.67   29.90    25.74    31.68    31.87    28.27
# 115  31.98  30.11  28.01   31.63    28.33    34.57    32.28    30.03
# 116  32.29  29.60  27.18   31.42    27.95    34.13    32.41    29.69

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   YEAR     117 non-null    int64
#  1   JAN      117 non-null    float64
#  2   FEB      117 non-null    float64
#  3   MAR      117 non-null    float64
#  4   APR      117 non-null    float64
#  5   MAY      117 non-null    float64
#  6   JUN      117 non-null    float64
#  7   JUL      117 non-null    float64
#  8   AUG      117 non-null    float64
#  9   SEP      117 non-null    float64
#  10  OCT      117 non-null    float64
#  11  NOV      117 non-null    float64
#  12  DEC      117 non-null    float64
#  13  ANNUAL   117 non-null    float64
#  14  JAN-FEB  117 non-null    float64
#  15  MAR-MAY  117 non-null    float64
#  16  JUN-SEP  117 non-null    float64
#  17  OCT-DEC  117 non-null    float64
# dtypes: float64(17), int64(1)
# memory usage: 16.6 KB

# %%
df.shape
# Out:
# (117, 18)

# %%
X = df[['YEAR']]
y = df['JAN']

model = LinearRegression()
model.fit(X, y)


y_pred = model.predict(X)

# %%
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)


print("Model Evaluation Metrics for January Temperature Prediction")
print(f"Mean Squared Error (MSE): {mse:.3f}")
print(f"Mean Absolute Error (MAE): {mae:.3f}")
print(f"R-Squared (R2 Score): {r2:.3f}")


plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Actual JAN Temperatures')
plt.plot(X, y_pred, color='red', linewidth=2, label='Regression Line')



plt.title('Linear Regression - January Temperature Prediction')
plt.xlabel('Year')
plt.ylabel('January Temperature (°C)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Model Evaluation Metrics for January Temperature Prediction
# Mean Squared Error (MSE): 0.462
# Mean Absolute Error (MAE): 0.527
# R-Squared (R2 Score): 0.331

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

X = df[['YEAR']]

months = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']

predictions = pd.DataFrame()
predictions['YEAR'] = df['YEAR']

models = {}
for month in months:
    y = df[month]


    model = LinearRegression()
    model.fit(X, y)

    predicted_temps = model.predict(X)

    predictions[month + '_PREDICTED'] = predicted_temps

    models[month] = model

predictions.head()
# Out:
#    YEAR  JAN_PREDICTED  FEB_PREDICTED  MAR_PREDICTED  APR_PREDICTED  \
# 0  1901      22.866136      24.324604      28.074032      31.153483
# 1  1902      22.880297      24.346557      28.091479      31.167661
# 2  1903      22.894457      24.368509      28.108926      31.181839
# 3  1904      22.908617      24.390462      28.126374      31.196017
# 4  1905      22.922778      24.412415      28.143821      31.210195
#
#    MAY_PREDICTED  JUN_PREDICTED  JUL_PREDICTED  AUG_PREDICTED  SEP_PREDICTED  \
# 0      33.059997      32.371709      30.652295      29.974915      29.868747
# 1      33.068709      32.378650      30.658908      29.984101      29.879402
# 2      33.077421      32.385591      30.665522      29.993287      29.890057
# 3      33.086133      32.392532      30.672136      30.002473      29.900713
# 4      33.094846      32.399472      30.678750      30.011658      29.911368
#
#    OCT_PREDICTED  NOV_PREDICTED  DEC_PREDICTED
# ...
